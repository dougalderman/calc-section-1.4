# %%
plot(-1/x, (x, -5, -.1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(-1/x, (x, 0.1, 5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(-1/x, x, -5, 5).show(ymin=-10, ymax=10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
derivative(-1/x, x)
# Out:
# x^(-2)

# %%
plot(x^(-2), x, -5, 5).show(ymin=-10, ymax=10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
(plot(-1/x, x, -3, 0)+plot(x+2, -3, 0, rgbcolor='red')+point((-1, 1), \
    rgbcolor='black', pointsize=30)).show(xmin=-3, xmax=0, ymin=0, ymax=3)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
(plot(-1/x, x, 0, 3)+plot(x/4-1, 0, 3, rgbcolor='red')+point((2, -0.5), \
    rgbcolor='black', pointsize=30)).show(xmin=0, xmax=3, ymin=-3, ymax=0)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
(plot(-1/x, x, -6, -4)+plot(x/25+0.4, -6, -4, rgbcolor='red')+point((-5, 0.2), \
    rgbcolor='black', pointsize=30)).show(xmin=-6, xmax=-4, ymin=0.1, ymax=0.3)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
plot(sgn(x-5)*abs(x-5)^(1/3), x, -10, 10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
derivative((x-5)^(1/3), x)
# Out:
# 1/3/(x - 5)^(2/3)

# %%
plot(1/3/(sgn((x - 5))*abs(x - 5)^(2/3)), x, -10, 10).show(ymin=-3, ymax=3)
# Out:
# Graphics object consisting of 1 graphics primitive
